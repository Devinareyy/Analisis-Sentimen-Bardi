# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import app
import pandas as pd #untukmembuatdataframe
import numpy as np #untukoperasivektroataumatriks

# %%
from google_play_scraper import Sort, reviews_all
us_reviews = reviews_all(
    'com.bardi.smart.home',
    sleep_milliseconds=0, # defaults to 0
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT

)

# %%
df_data = pd.DataFrame(np.array(us_reviews),columns=['review'])
df_data = df_data.join(pd.DataFrame(df_data.pop('review').tolist()))
df_data.head()
# Out:
#                                reviewId                    userName  \
# 0  c8213809-6a37-4f31-a3d4-70058be98870            Ade L. Biyantara
# 1  7dc44017-004d-4bd2-8645-0ca41f928058                   Vina Dewi
# 2  e7a8ec9c-e783-4267-a70c-0e46a9fe6b80           Martinus Wibisono
# 3  917a3a5d-cf84-4035-a4b8-4988b564bc91         Christian Hariyanto
# 4  4cdd4930-7875-4023-82da-19a0c2b27ddd  Friskadia Putri Ekinasmara
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a-/ACNPE...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  Ini aplikasi gimana si loading terus, baru bel...      1              0
# 1  App is so broken now. Force close on its own, ...      1              0
# 2  It crashes every single day, I have to restart...      3              0
# 3  Sangat buruk, skrg aplikasi tidak bisa buka ka...      1              0
# 4  Force close di xiao mi jd harus bolak balik di...      1              0
#
#   reviewCreatedVersion                  at  \
# 0                1.3.8 2022-11-28 15:21:58
# 1                1.3.8 2022-11-28 14:57:00
# 2                1.3.8 2022-11-28 14:42:57
# 3                1.3.8 2022-11-28 14:23:37
# 4                1.3.8 2022-11-28 14:11:17
#
#                                         replyContent           repliedAt
# 0  Hai Kak, kami siap melayani kakak perihal kend... 2022-11-28 17:42:17
# 1  Hai Kak, kami siap melayani kakak perihal kend... 2022-11-28 17:42:10
# 2  Hai Kak, kami siap melayani kakak perihal kend... 2022-11-28 17:42:05
# 3  Hai Kak, kami siap melayani kakak perihal kend... 2022-11-28 17:41:45
# 4  Hai Kak, kami siap melayani kakak perihal kend... 2022-06-05 14:30:00

# %%
len(df_data.index)
# Out:
# 1747

# %%
df_data[['userName', 'score','at', 'content']].head()
# Out:
#                      userName  score                  at  \
# 0            Ade L. Biyantara      1 2022-11-28 15:21:58
# 1                   Vina Dewi      1 2022-11-28 14:57:00
# 2           Martinus Wibisono      3 2022-11-28 14:42:57
# 3         Christian Hariyanto      1 2022-11-28 14:23:37
# 4  Friskadia Putri Ekinasmara      1 2022-11-28 14:11:17
#
#                                              content
# 0  Ini aplikasi gimana si loading terus, baru bel...
# 1  App is so broken now. Force close on its own, ...
# 2  It crashes every single day, I have to restart...
# 3  Sangat buruk, skrg aplikasi tidak bisa buka ka...
# 4  Force close di xiao mi jd harus bolak balik di...

# %%
review = df_data[['userName', 'score','at', 'content']]
sorted_df = review.sort_values(by='at', ascending=False) 
sorted_df.head()
# Out:
#                      userName  score                  at  \
# 0            Ade L. Biyantara      1 2022-11-28 15:21:58
# 1                   Vina Dewi      1 2022-11-28 14:57:00
# 2           Martinus Wibisono      3 2022-11-28 14:42:57
# 3         Christian Hariyanto      1 2022-11-28 14:23:37
# 4  Friskadia Putri Ekinasmara      1 2022-11-28 14:11:17
#
#                                              content
# 0  Ini aplikasi gimana si loading terus, baru bel...
# 1  App is so broken now. Force close on its own, ...
# 2  It crashes every single day, I have to restart...
# 3  Sangat buruk, skrg aplikasi tidak bisa buka ka...
# 4  Force close di xiao mi jd harus bolak balik di...

# %%
ss = sorted_df[['userName', 'score','at', 'content']]

# %%
ss.head()
# Out:
#                      userName  score                  at  \
# 0            Ade L. Biyantara      1 2022-11-28 15:21:58
# 1                   Vina Dewi      1 2022-11-28 14:57:00
# 2           Martinus Wibisono      3 2022-11-28 14:42:57
# 3         Christian Hariyanto      1 2022-11-28 14:23:37
# 4  Friskadia Putri Ekinasmara      1 2022-11-28 14:11:17
#
#                                              content
# 0  Ini aplikasi gimana si loading terus, baru bel...
# 1  App is so broken now. Force close on its own, ...
# 2  It crashes every single day, I have to restart...
# 3  Sangat buruk, skrg aplikasi tidak bisa buka ka...
# 4  Force close di xiao mi jd harus bolak balik di...

# %%
ss.to_csv("bardi.csv", index = 2500)
